# %%
# Import Statements
import pandas as pd
import folium
from folium import plugins

# %%
# Load Data
breweries = pd.read_csv('Data/wa_breweries.csv')

# %%
breweries.head()
# Out:
#                       brewery satellite_location brewery_type  \
# 0         192 Brewing Company       Mount Vernon      taproom
# 1         192 Brewing Company                NaN      brewpub
# 2  20 Corners Brewing Company                NaN      brewpub
# 3         210 Brewing Company                NaN      taproom
# 4            23rd Ave Brewery                NaN        micro
#
#                        address          city  zipcode     county   latitude  \
# 0        1405 South 2nd Street  Mount Vernon    98273     Skagit  48.411774
# 1   7324 NE 175th Street Ste F       Kenmore    98028       King  47.756677
# 2  14148 NE 190th St - Suite A   Woodinville    98072       King  47.765067
# 3     3438 Stoluckquamish Lane     Arlington    98223  Snohomish  48.213532
# 4            2313 S Jackson St       Seattle    98144       King  47.599270
#
#     longitude  year_established  guild_member  production_data_2017  \
# 0 -122.337970              2010             1                     1
# 1 -122.242502              2010             1                     1
# 2 -122.151015              2016             0                     1
# 3 -122.184854              2015             1                     1
# 4 -122.301800              2018             0                     0
#
#    production_data_2022  closed_since_2022  \
# 0                     1                  1
# 1                     1                  0
# 2                     1                  0
# 3                     0                  0
# 4                     1                  0
#
#                           untappd_profile_link
# 0             https://untappd.com/192BrewingCo
# 1             https://untappd.com/192BrewingCo
# 2  https://untappd.com/20CornersBrewingCompany
# 3               https://untappd.com/210Brewing
# 4           https://untappd.com/23rdAveBrewery

# %%
# Base Map
base_map = folium.Map(location=[47.7511, -120.7401], zoom_start=7)

# Add Markers for Breweries
for index, row in breweries.iterrows():
    brewery_name = row['brewery']
    
    # Clean latitude and longitude values
    brewery_lat = row['latitude']
    brewery_lon = row['longitude']
    
    brewery_popup = f"{brewery_name}"
    folium.Marker(location=[brewery_lat, brewery_lon], popup=brewery_popup,
                     icon=folium.Icon(color='blue', icon='circle', prefix='fa')).add_to(base_map)
    
# Display Map
base_map.save("Viz/breweries_map.html")
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cdcccd7c01b93df4cf46787fdfa46d0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cdcccd7c01b93df4cf46787fdfa46d0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cdcccd7c01b93df4cf46787fdfa46d0d = L.map(
#                 &quot;map_cdcccd7c01b93df4cf46787fdfa46d0d&quot;,
#                 {
#                     center: [47.7511, -120.7401],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_daa401784496e54d587b039c25ccced2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_daa401784496e54d587b039c25ccced2.addTo(map_cdcccd7c01b93df4cf46787fdfa46d0d);
#
#
#             var marker_b47d76d55848d40a9d6f767c248d0a95 = L.marker(
#                 [48.41177416, -122.3379704],
#                 {}
#             ).addTo(map_cdcccd7c01b93df4cf46787fdfa46d0d);
#
#
#             var icon_47c581dedba5fc98827ed5b04768ff37 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b47d76d55848d40a9d6f767c248d0a95.setIcon(icon_47c581dedba5fc98827ed5b04768ff37);
#
#
#         var popup_a7e9cfcf5d8973e6515d3730c665613a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9abb9041282997ac1c10db5281244038 = $(`&lt;div id=&quot;html_9abb9041282997ac1c10db5281244038&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;192 Brewing Company&lt;/div&gt;`)[0];
#                 popup_a7e9cfcf5d8973e6515d3730c665613a.setContent(html_9abb9041282997ac1c10db5281244038);
#
#
#
#         marker_b47d76d55848d40a9d6f767c248d0a95.bindPopup(popup_a7e9cfcf5d8973e6515d3730c665613a)
#         ;
#
#
#
#
#             var marker_5f8c5211c44972a84373be7a4b747b3c = L.marker(
#                 [47.7566771, -122.2425016],
#                 {}
#             ).addTo(map_cdcccd7c01b93df4cf46787fdfa46d0d);
#
#
#             var icon_700d7e5db0d5176e7e5a25adb9af9732 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5f8c5211c44972a84373be7a4b747b3c.setIcon(icon_700d7e5db0d5176e7e5a25adb9af9732);
#
#
#         var popup_220078fb2a8782c1043f9ca5137622cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f83f914efb8282405f28b837e698891d = $(`&lt;div id=&quot;html_f83f914efb8282405f28b837e698891d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;192 Brewing Company&lt;/div&gt;`)[0];
#                 popup_220078fb2a8782c1043f9ca5137622cd.setContent(html_f83f914efb8282405f28b837e698891d);
#
#
#
#         marker_5f8c5211c44972a84373be7a4b747b3c.bindPopup(popup_220078fb2a8782c1043f9ca5137622cd)
#         ;
#
#
#
#
#             var marker_c65a857eb95efe9229678370fa282e1d = L.marker(
#                 [47.76506654, -122.1510149],
#                 {}
#             ).addTo(map_cdcccd7c01b93df4cf46787fdfa46d0d);
#
#
#             var icon_29109d5d802d8d6957a437ceb23111fd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c65a857eb95efe9229678370fa282e1d.setIcon(icon_29109d5d802d8d6957a437ceb23111fd);
#
#
#         var popup_25c206659ef8b2ee7a7ca7a957f50c99 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_956ceae1b5eb3405a875b49dae3f0a8a = $(`&lt;div id=&quot;html_956ceae1b5eb3405a875b49dae3f0a8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;20 Corners Brewing Company&lt;/div&gt;`)[0];
#                 popup_25c206659ef8b2ee7a7ca7a957f50c99.setContent(html_956ceae1b5eb3405a875b49dae3f0a8a);
#
#
#
#         marker_c65a857eb95efe9229678370fa282e1d.bindPopup(popup_25c206659ef8b2ee7a7ca7a957f50c99)
#         ;
#
#
#
#
#             var marker_6e74d45e7d6f384663123ace15dcf592 = L.marker(
#                 [48.2135319, -122.1848541],
#                 {}
#             ).addTo(map_cdcccd7c01b93df4cf46787fdfa46d0d);
#
#
#             var icon_3037b78607ec954dca189cc186205665 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quo

# %%
# Close Base Map
base_map_close = folium.Map(location=[47.7511, -120.7401], zoom_start=7)

# Closed Breweries
breweries_close = breweries[breweries['closed_since_2022'] == 1]

# Add Markers for Breweries
for index, row in breweries_close.iterrows():
    brewery_name = row['brewery']
    
    # Clean latitude and longitude values
    brewery_lat = row['latitude']
    brewery_lon = row['longitude']
    
    brewery_popup = f"{brewery_name}"
    folium.Marker(location=[brewery_lat, brewery_lon], popup=brewery_popup,
                     icon=folium.Icon(color='red', icon='circle', prefix='fa')).add_to(base_map_close)
    
# Display Map
base_map_close.save("Viz/breweries_closed_map.html")
base_map_close
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96326f8ee578712cd64d301f196ccf92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96326f8ee578712cd64d301f196ccf92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_96326f8ee578712cd64d301f196ccf92 = L.map(
#                 &quot;map_96326f8ee578712cd64d301f196ccf92&quot;,
#                 {
#                     center: [47.7511, -120.7401],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7ec38e8b3036314720b32f3262ad1ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e7ec38e8b3036314720b32f3262ad1ef.addTo(map_96326f8ee578712cd64d301f196ccf92);
#
#
#             var marker_91bec7162830e3e5061391f1ab30d48d = L.marker(
#                 [48.41177416, -122.3379704],
#                 {}
#             ).addTo(map_96326f8ee578712cd64d301f196ccf92);
#
#
#             var icon_73520d90cb3503ecf8f1fac8e1454cd2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_91bec7162830e3e5061391f1ab30d48d.setIcon(icon_73520d90cb3503ecf8f1fac8e1454cd2);
#
#
#         var popup_349fbda0e760442e079393477f25366c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_67889460ca85d1d033a53c0c2430741f = $(`&lt;div id=&quot;html_67889460ca85d1d033a53c0c2430741f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;192 Brewing Company&lt;/div&gt;`)[0];
#                 popup_349fbda0e760442e079393477f25366c.setContent(html_67889460ca85d1d033a53c0c2430741f);
#
#
#
#         marker_91bec7162830e3e5061391f1ab30d48d.bindPopup(popup_349fbda0e760442e079393477f25366c)
#         ;
#
#
#
#
#             var marker_c0157fe2df1ab741b756300e29cf0433 = L.marker(
#                 [47.71758683, -117.4328496],
#                 {}
#             ).addTo(map_96326f8ee578712cd64d301f196ccf92);
#
#
#             var icon_85bf0e0eeb7de163f2c711bbb78fffb7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c0157fe2df1ab741b756300e29cf0433.setIcon(icon_85bf0e0eeb7de163f2c711bbb78fffb7);
#
#
#         var popup_f03ace06c8bdd6271926e4ecad122758 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_18882b90e256d5a82168368070798cb7 = $(`&lt;div id=&quot;html_18882b90e256d5a82168368070798cb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5 North Brewing Company&lt;/div&gt;`)[0];
#                 popup_f03ace06c8bdd6271926e4ecad122758.setContent(html_18882b90e256d5a82168368070798cb7);
#
#
#
#         marker_c0157fe2df1ab741b756300e29cf0433.bindPopup(popup_f03ace06c8bdd6271926e4ecad122758)
#         ;
#
#
#
#
#             var marker_35a615c9a2208344db3ae061760c2ed7 = L.marker(
#                 [45.58542289, -122.4038144],
#                 {}
#             ).addTo(map_96326f8ee578712cd64d301f196ccf92);
#
#
#             var icon_24d98c37c7dec08c85cb2ced2d8bb023 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_35a615c9a2208344db3ae061760c2ed7.setIcon(icon_24d98c37c7dec08c85cb2ced2d8bb023);
#
#
#         var popup_d3fd2aa798d6d99a5a51e8d3ca058837 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb680c4e42100df3e9ab496a23622077 = $(`&lt;div id=&quot;html_fb680c4e42100df3e9ab496a23622077&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Camas Brewing Company&lt;/div&gt;`)[0];
#                 popup_d3fd2aa798d6d99a5a51e8d3ca058837.setContent(html_fb680c4e42100df3e9ab496a23622077);
#
#
#
#         marker_35a615c9a2208344db3ae061760c2ed7.bindPopup(popup_d3fd2aa798d6d99a5a51e8d3ca058837)
#         ;
#
#
#
#
#             var marker_f95eb71f85aa15ccecd867b17f70d467 = L.marker(
#                 [47.75649976, -122.1685679],
#                 {}
#             ).addTo(map_96326f8ee578712cd64d301f196ccf92);
#
#
#             var icon_8077fcd91976847ac792feb4ba76780f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor
