# %%
# Import Statements
import pandas as pd
import folium

# %%
# Load Data
breweries = pd.read_csv('Data/wa_breweries.csv')

# %%
# Base Map
base_map = folium.Map(location=[47.7511, -120.7401], zoom_start=7)

# Add Markers for Breweries
for index, row in breweries.iterrows():
    brewery_name = row['brewery']
    
    # Clean latitude and longitude values
    brewery_lat = float(row['latitude'].strip(','))
    brewery_lon = float(row['longitude'].strip(','))
    
    brewery_popup = f"{brewery_name}"
    folium.Marker(location=[brewery_lat, brewery_lon], popup=brewery_popup).add_to(base_map)
    
# Display Map
base_map.save("Viz/breweries_map.html")
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85d17923546dcd698c16ed218f39f99e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85d17923546dcd698c16ed218f39f99e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85d17923546dcd698c16ed218f39f99e = L.map(
#                 &quot;map_85d17923546dcd698c16ed218f39f99e&quot;,
#                 {
#                     center: [47.7511, -120.7401],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0613b804578b4382aa69f93871cb970 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f0613b804578b4382aa69f93871cb970.addTo(map_85d17923546dcd698c16ed218f39f99e);
#
#
#             var marker_fc9ae9bcf3a504fee566aafce9c1ecec = L.marker(
#                 [48.41177416, -122.3379704],
#                 {}
#             ).addTo(map_85d17923546dcd698c16ed218f39f99e);
#
#
#         var popup_b98965cbd497d39bcae4bc036f51219f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44d4d51f0f7dd6fe9c2a7bff9df6999b = $(`&lt;div id=&quot;html_44d4d51f0f7dd6fe9c2a7bff9df6999b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;192 Brewing Company&lt;/div&gt;`)[0];
#                 popup_b98965cbd497d39bcae4bc036f51219f.setContent(html_44d4d51f0f7dd6fe9c2a7bff9df6999b);
#
#
#
#         marker_fc9ae9bcf3a504fee566aafce9c1ecec.bindPopup(popup_b98965cbd497d39bcae4bc036f51219f)
#         ;
#
#
#
#
#             var marker_8292261ca41b03149d51731126985852 = L.marker(
#                 [47.7566771, -122.2425016],
#                 {}
#             ).addTo(map_85d17923546dcd698c16ed218f39f99e);
#
#
#         var popup_9407061f62482fba29cf77b0c4c4afb8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4eaad906f5edbdc7dbcfc7eadd273fe1 = $(`&lt;div id=&quot;html_4eaad906f5edbdc7dbcfc7eadd273fe1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;192 Brewing Company&lt;/div&gt;`)[0];
#                 popup_9407061f62482fba29cf77b0c4c4afb8.setContent(html_4eaad906f5edbdc7dbcfc7eadd273fe1);
#
#
#
#         marker_8292261ca41b03149d51731126985852.bindPopup(popup_9407061f62482fba29cf77b0c4c4afb8)
#         ;
#
#
#
#
#             var marker_403105a2d1539886dd728f0450f73784 = L.marker(
#                 [47.76506654, -122.1510149],
#                 {}
#             ).addTo(map_85d17923546dcd698c16ed218f39f99e);
#
#
#         var popup_995c8000ba6ff533394b29870c5f0eb5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_acde5abffede77f58a9872a3c1203e11 = $(`&lt;div id=&quot;html_acde5abffede77f58a9872a3c1203e11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;20 Corners Brewing Company&lt;/div&gt;`)[0];
#                 popup_995c8000ba6ff533394b29870c5f0eb5.setContent(html_acde5abffede77f58a9872a3c1203e11);
#
#
#
#         marker_403105a2d1539886dd728f0450f73784.bindPopup(popup_995c8000ba6ff533394b29870c5f0eb5)
#         ;
#
#
#
#
#             var marker_e6aec799652bc48f1b101d05261effa8 = L.marker(
#                 [48.2135319, -122.1848541],
#                 {}
#             ).addTo(map_85d17923546dcd698c16ed218f39f99e);
#
#
#         var popup_e2780e4db6d69a1b268499dc627304c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_711a344ae0c044aec0ec023be663c518 = $(`&lt;div id=&quot;html_711a344ae0c044aec0ec023be663c518&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;210 Brewing Company&lt;/div&gt;`)[0];
#                 popup_e2780e4db6d69a1b268499dc627304c0.setContent(html_711a344ae0c044aec0ec023be663c518);
#
#
#
#         marker_e6aec799652bc48f1b101d05261effa8.bindPopup(popup_e2780e4db6d69a1b268499dc627304c0)
#         ;
#
#
#
#
#             var marker_533e9c5f7dce22553e37a0863c52b1d8 = L.marker(
#                 [47.59927, -122.3018],
#                 {}
#             ).addTo(map_85d17923546dcd698c16ed218f39f99e);
#
#
#         var popup_b7f35b6a85daa19353a64d6000deb8e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1fbb74c6003555efc30deace3c565c48 = $(`&lt;div id=&quot;html_1fbb74c6003555efc30deace3c565c48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;23rd Ave Brewery&lt;/div&gt;`)[0];
#                 popup_b7f35b6a85daa19353a64d6000deb8e0.setContent(html_1fbb74c6003555efc30deace3c565c48);
#
#
#
#         marker_533e9c5f7dce22553e37a0863c52b1d8.bindPopup(popup_b7f35b6a85daa19353a64d6000deb8e0)
#         ;
#
#
#
#
#             var marker_e90d502bafb9fb3ea8fccb5b58e54a06 = L.marker(
#                 [47.84617437, -122.2201877],
#                 {}
