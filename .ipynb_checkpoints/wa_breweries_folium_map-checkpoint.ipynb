# %%
# Import Statements
import pandas as pd
import folium
from folium import plugins

# %%
# Load Data
breweries = pd.read_csv('Data/wa_breweries.csv')

# %%
# Base Map
base_map = folium.Map(location=[47.7511, -120.7401], zoom_start=7)

# Add Markers for Breweries
for index, row in breweries.iterrows():
    brewery_name = row['brewery']
    
    # Clean latitude and longitude values
    brewery_lat = row['latitude']
    brewery_lon = row['longitude']
    
    brewery_popup = f"{brewery_name}"
    folium.Marker(location=[brewery_lat, brewery_lon], popup=brewery_popup).add_to(base_map)
    
# Display Map
base_map.save("Viz/breweries_map.html")
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46901229554fbb1b656263f079d000aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46901229554fbb1b656263f079d000aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46901229554fbb1b656263f079d000aa = L.map(
#                 &quot;map_46901229554fbb1b656263f079d000aa&quot;,
#                 {
#                     center: [47.7511, -120.7401],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88c3805ec433d55403a2a49e607953d9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_88c3805ec433d55403a2a49e607953d9.addTo(map_46901229554fbb1b656263f079d000aa);
#
#
#             var marker_e5bf62629d8b70a7ab086741ac0e6f7d = L.marker(
#                 [48.41177416, -122.3379704],
#                 {}
#             ).addTo(map_46901229554fbb1b656263f079d000aa);
#
#
#             var icon_ae676772aad001c356f893ad365dc586 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e5bf62629d8b70a7ab086741ac0e6f7d.setIcon(icon_ae676772aad001c356f893ad365dc586);
#
#
#         var popup_2c6566857a0c9faa2349bc8a252f68c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bcd17030686a3107f31d9b7785e0798e = $(`&lt;div id=&quot;html_bcd17030686a3107f31d9b7785e0798e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;192 Brewing Company&lt;/div&gt;`)[0];
#                 popup_2c6566857a0c9faa2349bc8a252f68c1.setContent(html_bcd17030686a3107f31d9b7785e0798e);
#
#
#
#         marker_e5bf62629d8b70a7ab086741ac0e6f7d.bindPopup(popup_2c6566857a0c9faa2349bc8a252f68c1)
#         ;
#
#
#
#
#             var marker_06cc0d7d1f88a0910f4492ffca489279 = L.marker(
#                 [47.7566771, -122.2425016],
#                 {}
#             ).addTo(map_46901229554fbb1b656263f079d000aa);
#
#
#             var icon_48ba0363c33b5c0da3f932fa1402167a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_06cc0d7d1f88a0910f4492ffca489279.setIcon(icon_48ba0363c33b5c0da3f932fa1402167a);
#
#
#         var popup_99db4d420df74bd4c02b38ee0826167e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_561fb207c763dae2a297961cba3d3dff = $(`&lt;div id=&quot;html_561fb207c763dae2a297961cba3d3dff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;192 Brewing Company&lt;/div&gt;`)[0];
#                 popup_99db4d420df74bd4c02b38ee0826167e.setContent(html_561fb207c763dae2a297961cba3d3dff);
#
#
#
#         marker_06cc0d7d1f88a0910f4492ffca489279.bindPopup(popup_99db4d420df74bd4c02b38ee0826167e)
#         ;
#
#
#
#
#             var marker_b8494ca84c015f18fe6eda61babcc757 = L.marker(
#                 [47.76506654, -122.1510149],
#                 {}
#             ).addTo(map_46901229554fbb1b656263f079d000aa);
#
#
#             var icon_c99fc95fd745f74d3928f9cb75d4fe30 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b8494ca84c015f18fe6eda61babcc757.setIcon(icon_c99fc95fd745f74d3928f9cb75d4fe30);
#
#
#         var popup_d9d1c8119d8c88b3d4c0ee5faf543281 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_249a0ed63f9490c57b2739d309577198 = $(`&lt;div id=&quot;html_249a0ed63f9490c57b2739d309577198&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;20 Corners Brewing Company&lt;/div&gt;`)[0];
#                 popup_d9d1c8119d8c88b3d4c0ee5faf543281.setContent(html_249a0ed63f9490c57b2739d309577198);
#
#
#
#         marker_b8494ca84c015f18fe6eda61babcc757.bindPopup(popup_d9d1c8119d8c88b3d4c0ee5faf543281)
#         ;
#
#
#
#
#             var marker_fd2bfe9a481ad3258caffe743d78842d = L.marker(
#                 [48.2135319, -122.1848541],
#                 {}
#             ).addTo(map_46901229554fbb1b656263f079d000aa);
#
#
#             var icon_bb25aeae4519390b7a27725222b4e6e2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;
