# %%
# import statements
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

# settings
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# load data
prod22 = pd.read_csv('Data/brewery_production_2022_melted.csv')

# remove total annual rows
prod22 = prod22[prod22['month'] != 'total_annual']
prod22.reset_index(inplace=True, drop=True)

# %%
# get breweries that opened in 2022
brew22 = prod22[prod22['year_established'] == 2022][['brewery']].drop_duplicates()['brewery'].tolist()
#brew22

# month of 2022 breweries
opening_month = {
    'Bizarre Brewing':10,
    'Byron Street Brewery':7,
    'Cursed Brewing':10,
    'Hildegard Ferments and Botanicals':10,
    'No Drought Brewing Company':2, #here
    'Peace of Mind Brewing':2,
    'Remlinger Farm Brewery':2,
    'Ridgefield Craft Brewing Company':2,
    'Snow Eater Brewing Company':2,
    'Uprise Brewing Company':2,
    'Vice Beer':2,
    'Wild Oak Project':2,
    '45 Degree Brewhouse':2,
    'High Bluff Brewing':2,
    'Spokanite Brewing':2,
    'Top Knot Brewing':2,
    'Darach Brewing Company':2,
    'Common Language Brewing Company':2,
    'Griffin Brewing Pilot House':2,
    'New Maitland Brewing Llc':2
}

# input zeros for months prior to opening
months = {1:'January', 2:'February', 3:'March', 4:'April', 5:'May', 6:'June',
         7:'July', 8:'August', 9:'September', 10:'October', 11:'November', 12:'December'}

for k,v in opening_month.items():
    m = [value for key, value in months.items() if key < v]
    prod22['production'] = np.where((prod22['brewery'] == k) & (prod22['production'].isna()) & 
                                    (prod22['month'].isin(m)), 0, prod22['production'])

# %%
# check for consecutive nulls
prod22['is_null'] = prod22['production'].isnull().astype(int)
prod22['consec_nulls'] = prod22.groupby(['brewery', prod22['is_null'].eq(0).cumsum()])['is_null'].cumsum()
prod22['max_consec_nulls'] =  prod22.groupby(['brewery'])['consec_nulls'].transform(max)

# %%
# interpolate for breweries with 3 or fewer consecutive nulls
prod22['linear_interpolation'] = prod22.groupby('brewery')['production'].transform(
    lambda x: x.interpolate(method='linear', limit_direction='both')).reset_index()['production']

prod22['interpolated'] = np.where((prod22['max_consec_nulls'] <= 3) & (prod22['production'].isnull()), 1, 0)

prod22['production'] = np.round(
        np.where((prod22['max_consec_nulls'] <= 3) & (prod22['max_consec_nulls'] > 0),
            prod22['linear_interpolation'],
            prod22['production']), 2)

# %%
# calculate annual totals
cols = ['brewery','brewery_type','address', 'city','zipcode','county',
        'latitude','longitude','year_established','guild_member',
        'closed_since_2022','untappd_profile_link']

annuals1 = pd.DataFrame(prod22[prod22['max_consec_nulls'] <= 3].groupby(cols)['production'].sum().reset_index())

annuals2 = pd.DataFrame(prod22[prod22['max_consec_nulls'] > 3][cols]).drop_duplicates().reset_index(drop=True)
annuals2['production'] = np.NaN

annuals = pd.concat([annuals1, annuals2]).reset_index(drop=True)
annuals['month'] = 'total_annual'

# merge back into prod22
prod22 = pd.concat([prod22, annuals])

# set order
months = ['January','February','March','April','May','June','July',
        'August','September','October','November','December','total_annual']
prod22['month'] = pd.Categorical(prod22['month'], months)
prod22 = prod22.sort_values(by=['brewery', 'month']).reset_index(drop=True)

# %%
# drop unnecessary columns
cols_to_drop = ['is_null','consec_nulls','max_consec_nulls','linear_interpolation']
prod22.drop(columns=cols_to_drop, axis=1, inplace=True)

# %%
# save data
prod22.to_csv('Data/brewery_production_2022_melted_interpolated.csv', index=False)
# Out:
#                        brewery brewery_type                      address  \
# 0          192 Brewing Company      brewpub   7324 NE 175th Street Ste F
# 1          192 Brewing Company      brewpub   7324 NE 175th Street Ste F
# 2          192 Brewing Company      brewpub   7324 NE 175th Street Ste F
# 3          192 Brewing Company      brewpub   7324 NE 175th Street Ste F
# 4          192 Brewing Company      brewpub   7324 NE 175th Street Ste F
# 5          192 Brewing Company      brewpub   7324 NE 175th Street Ste F
# 6          192 Brewing Company      brewpub   7324 NE 175th Street Ste F
# 7          192 Brewing Company      brewpub   7324 NE 175th Street Ste F
# 8          192 Brewing Company      brewpub   7324 NE 175th Street Ste F
# 9          192 Brewing Company      brewpub   7324 NE 175th Street Ste F
# 10         192 Brewing Company      brewpub   7324 NE 175th Street Ste F
# 11         192 Brewing Company      brewpub   7324 NE 175th Street Ste F
# 12         192 Brewing Company      brewpub   7324 NE 175th Street Ste F
# 13  20 Corners Brewing Company      brewpub  14148 NE 190th St - Suite A
# 14  20 Corners Brewing Company      brewpub  14148 NE 190th St - Suite A
# 15  20 Corners Brewing Company      brewpub  14148 NE 190th St - Suite A
# 16  20 Corners Brewing Company      brewpub  14148 NE 190th St - Suite A
# 17  20 Corners Brewing Company      brewpub  14148 NE 190th St - Suite A
# 18  20 Corners Brewing Company      brewpub  14148 NE 190th St - Suite A
# 19  20 Corners Brewing Company      brewpub  14148 NE 190th St - Suite A
# 20  20 Corners Brewing Company      brewpub  14148 NE 190th St - Suite A
# 21  20 Corners Brewing Company      brewpub  14148 NE 190th St - Suite A
# 22  20 Corners Brewing Company      brewpub  14148 NE 190th St - Suite A
# 23  20 Corners Brewing Company      brewpub  14148 NE 190th St - Suite A
# 24  20 Corners Brewing Company      brewpub  14148 NE 190th St - Suite A
# 25  20 Corners Brewing Company      brewpub  14148 NE 190th St - Suite A
#
#            city  zipcode county   latitude   longitude  year_established  \
# 0       Kenmore    98028   King  47.756677 -122.242502              2010
# 1       Kenmore    98028   King  47.756677 -122.242502              2010
# 2       Kenmore    98028   King  47.756677 -122.242502              2010
# 3       Kenmore    98028   King  47.756677 -122.242502              2010
# 4       Kenmore    98028   King  47.756677 -122.242502              2010
# 5       Kenmore    98028   King  47.756677 -122.242502              2010
# 6       Kenmore    98028   King  47.756677 -122.242502              2010
# 7       Kenmore    98028   King  47.756677 -122.242502              2010
# 8       Kenmore    98028   King  47.756677 -122.242502              2010
# 9       Kenmore    98028   King  47.756677 -122.242502              2010
# 10      Kenmore    98028   King  47.756677 -122.242502              2010
# 11      Kenmore    98028   King  47.756677 -122.242502              2010
# 12      Kenmore    98028   King  47.756677 -122.242502              2010
# 13  Woodinville    98072   King  47.765067 -122.151015              2016
# 14  Woodinville    98072   King  47.765067 -122.151015              2016
