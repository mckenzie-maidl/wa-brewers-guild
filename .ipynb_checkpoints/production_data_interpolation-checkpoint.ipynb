# %%
# import statements
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

#from fancyimpute import KNN
#from fancyimpute import IterativeImputer
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer

# settings
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# load data
prod22 = pd.read_csv('Data/brewery_production_2022_melted.csv')

# remove total column
prod22 = prod22[prod22['month'] != 'total_annual']

# %%
# get breweries that opened in 2022
brew22 = prod22[prod22['year_established'] == 2022][['brewery']].drop_duplicates()['brewery'].tolist()
#brew22

# month of 2022 breweries
opening_month = {
    'Bizarre Brewing':10,
    'Byron Street Brewery':7,
    'Cursed Brewing':10,
    'Hildegard Ferments and Botanicals':2, #here
    'Hop Chaos Brewing Company':2,
    'Ladd and Lass Brewing':2,
    'Natural 20 Brewing Company':2,
    'No Drought Brewing Company':2,
    'Peace of Mind Brewing':2,
    'Remlinger Farm Brewery':2,
    'Ridgefield Craft Brewing Company':2,
    'Snow Eater Brewing Company':2,
    'Uprise Brewing Company':2,
    'Vice Beer':2,
    'Wild Oak Project':2,
    '45 Degree Brewhouse':2,
    'High Bluff Brewing':2,
    'Spokanite Brewing':2,
    'Top Knot Brewing':2,
    'Darach Brewing Company':2,
    'Common Language Brewing Company':2,
    'Griffin Brewing Pilot House':2,
    'New Maitland Brewing Llc':2
}

# input zeros for months prior to opening
months = {1:'January', 2:'February', 3:'March', 4:'April', 5:'May', 6:'June',
         7:'July', 8:'August', 9:'September', 10:'October', 11:'November', 12:'December'}

for k,v in opening_month.items():
    m = [value for key, value in months.items() if key < v]
    prod22['production'] = np.where((prod22['brewery'] == k) & (prod22['production'].isna()) & 
                                    (prod22['month'].isin(m)), 0, prod22['production'])

# %%
# check for consecutive nulls
prod22['is_null'] = prod22['production'].isnull().astype(int)
prod22['consec_nulls'] = prod22.groupby(['brewery', prod22['is_null'].eq(0).cumsum()])['is_null'].cumsum()
prod22['max_consec_nulls'] =  prod22.groupby(['brewery'])['consec_nulls'].transform(max)

# drop unnecessary columns
prod22.drop(columns=['is_null', 'consec_nulls'], inplace=True)

# %%
# testing
prod22[['brewery','production']].groupby('brewery').apply(lambda group: group.interpolate(method='quadratic'))
# Out:
# 0                NaN
# 1           0.500000
# 2           0.388759
# 3           0.310681
# 4           0.265766
# 5           0.254014
# 6           0.275426
# 7           0.330000
# 8           0.417738
# 9           0.538638
# 10          0.692702
# 11          2.981958
# 13         53.904592
# 14        104.640000
# 15        147.980000
# 16         72.330000
# 17         56.690496
# 18        134.935704
# 19        216.278060
# 20        209.930000
# 21        132.300000
# 22         81.838913
# 23         75.860000
# 24        106.500000
# 26        111.043797
# 27         76.179545
# 28         36.442060
# 29         11.715545
# 30          2.000000
# 31          4.780000
# 32          5.000000
# 33          0.366587
# 34          1.000000
# 35         14.000000
# 36         21.465723
# 37         20.413690
# 39          5.661978
# 40          2.000000
# 41          1.250000
# 42          3.160418
# 43          4.720000
# 44          2.959420
# 45          1.460000
# ...

# %%
# interpolate (quadratic) for breweries with 3 or fewer consecutive nulls
prod22[(prod22['max_consec_nulls'] <= 3) & (prod22['max_consec_nulls'] > 0)]

# quadratic_interp['co2'] = quadratic_interp['co2'].interpolate(method = 'quadratic')
# quadratic_interp.loc[slovenia_na['co2'] == True]
#df.groupby('filename').apply(lambda group: group.interpolate(method='index'))

prod22['production'] np.where((prod22['max_consec_nulls'] <= 3) & (prod22['max_consec_nulls'] > 0),
                             '',
                             prod22['production'])


# HERE!
# Out:
#                                      brewery brewery_type  \
# 13                20 Corners Brewing Company      brewpub
# 14                20 Corners Brewing Company      brewpub
# 15                20 Corners Brewing Company      brewpub
# 16                20 Corners Brewing Company      brewpub
# 17                20 Corners Brewing Company      brewpub
# 18                20 Corners Brewing Company      brewpub
# 19                20 Corners Brewing Company      brewpub
# 20                20 Corners Brewing Company      brewpub
# 21                20 Corners Brewing Company      brewpub
# 22                20 Corners Brewing Company      brewpub
# 23                20 Corners Brewing Company      brewpub
# 24                20 Corners Brewing Company      brewpub
# 65                  5 Rights Brewing Company      brewpub
# 66                  5 Rights Brewing Company      brewpub
# 67                  5 Rights Brewing Company      brewpub
# ...

# %%
# set total values of production grouped by brewery (null for consecutive missing > 3)
